# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
pip install --upgrade --force-reinstall fars-cleaner
# Out:
# ...
#   Using cached fars_cleaner-1.3.5-py3-none-any.whl (3.6 MB)
# ...
#   Using cached pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# ...
#   Using cached pyjanitor-0.23.1-py3-none-any.whl (147 kB)
# ...
#   Using cached numpy-1.26.0-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# ...
#   Using cached dask-2023.9.2-py3-none-any.whl (1.2 MB)
# ...
#   Using cached pathlib-1.0.1-py3-none-any.whl (14 kB)
# ...
#   Using cached scipy-1.11.2-cp39-cp39-macosx_10_9_x86_64.whl (37.2 MB)
# ...
#   Using cached pooch-1.7.0-py3-none-any.whl (60 kB)
# ...
#   Using cached thefuzz-0.20.0-py3-none-any.whl (15 kB)
# ...
#   Using cached distributed-2022.12.1-py3-none-any.whl (930 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# ...
#   Using cached urllib3-2.0.4-py3-none-any.whl (123 kB)
# ...
